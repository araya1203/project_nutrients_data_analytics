# %%
import pandas as pd

# %%
# df_cholesterol=pd.read_csv('../datasets/reviews_data/cholesterol_reviews.csv')
# df_cholesterol

# %%
# df_cholesterol.columns

# %%
# df_liver=pd.read_csv('../datasets/reviews_data/liver.csv')
# df_liver.columns

# %%
# df_cholesterol=df_cholesterol[['_id','product_name','review_date','review_content','review_star','review_writer']]

# %%
# df_cholesterol

# %%
# df_eyes=pd.read_csv('../datasets/reviews_data/eyes.csv')
# df_eyes

# %%
# df_recovery=pd.read_csv('../datasets/reviews_data/recovery.csv')
# df_recovery

# %%
# df_cholesterol=df_cholesterol.drop(columns=['_id'])

# %%
# df_liver=df_liver.drop(columns=['Unnamed: 0'])

# %%
# df_eyes=df_eyes.drop(columns=['Unnamed: 0'])

# %%
# df_recovery=df_recovery.drop(columns=['Unnamed: 0'])

# %%
# merged_df = pd.concat([df_cholesterol, df_liver, df_eyes, df_recovery], ignore_index=True)

# %%
# merged_df.to_csv('../datasets/reviews_data/all_product.csv', index=False)

# %%
df_all=pd.read_csv('../datasets/reviews_data/all_product.csv')
df_all
# Out:
#                                              product_name review_date  \
# 0       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2021.03.19
# 1       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2023.07.05
# 2       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2023.09.20
# 3       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2023.09.19
# 4       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2021.11.16
# ...                                                   ...         ...
# 110953              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.15
# 110954              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.07
# 110955              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.06.16
# 110956              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.04.06
# 110957              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.27
#
#                                            review_content  review_star  \
# ...

# %%
# "product_name" 컬럼에서 "강아지"를 포함한 레코드 선택
selected_rows = df_all[df_all['product_name'].str.contains('강아지')]

# %%
selected_rows
# Out:
#                                             product_name review_date  \
# 22561                            스완슨 밀크시슬,원산지미국,강아지 간영양제  2014.07.23
# 22562                            스완슨 밀크시슬,원산지미국,강아지 간영양제  2016.06.24
# 22563                            스완슨 밀크시슬,원산지미국,강아지 간영양제  2014.08.18
# 22564                            스완슨 밀크시슬,원산지미국,강아지 간영양제  2017.05.07
# 22565                            스완슨 밀크시슬,원산지미국,강아지 간영양제  2016.05.24
# ...                                                  ...         ...
# 23503  [2박스] 강아지 간 영양제 노화 무기력 식욕부진 소화불량 눈물자국 위드펫바이오 일...  2023.02.02
# 23504  [2박스] 강아지 간 영양제 노화 무기력 식욕부진 소화불량 눈물자국 위드펫바이오 일...  2023.02.03
# 23505  [2박스] 강아지 간 영양제 노화 무기력 식욕부진 소화불량 눈물자국 위드펫바이오 일...  2023.02.09
# 23506  [2박스] 강아지 간 영양제 노화 무기력 식욕부진 소화불량 눈물자국 위드펫바이오 일...  2023.02.08
# 23507  [2박스] 강아지 간 영양제 노화 무기력 식욕부진 소화불량 눈물자국 위드펫바이오 일...  2023.02.06
#
#                                           review_content  review_star  \
# ...

# %%
df_all = df_all[~df_all['product_name'].str.contains('강아지')]

# %%
df_all
# Out:
#                                              product_name review_date  \
# 0       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2021.03.19
# 1       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2023.07.05
# 2       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2023.09.20
# 3       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2023.09.19
# 4       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2021.11.16
# ...                                                   ...         ...
# 110953              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.15
# 110954              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.07
# 110955              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.06.16
# 110956              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.04.06
# 110957              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.27
#
#                                            review_content  review_star  \
# ...

# %%
selected_rows = df_all[df_all['product_name'].str.contains('강아지')]
selected_rows
# Out:
# Empty DataFrame
# Columns: [product_name, review_date, review_content, review_star, review_writer]
# Index: []

# %%
df_all=df_all.drop_duplicates()

# %%
df_all
# Out:
#                                              product_name review_date  \
# 0       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2021.03.19
# 1       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2023.07.05
# 2       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2023.09.20
# 3       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2023.09.19
# 4       브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...  2021.11.16
# ...                                                   ...         ...
# 110953              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.15
# 110954              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.07
# 110955              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.06.16
# 110956              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.04.06
# 110957              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.27
#
#                                            review_content  review_star  \
# ...

# %%
df_all.to_csv('../datasets/reviews_data/all_product.csv', index=False)
