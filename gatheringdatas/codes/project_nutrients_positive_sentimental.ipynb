# %%
import pandas as pd

# %%
df_positive=pd.read_csv('../datasets/reviews_data/all_preprocess_positive.csv')

# %% [markdown]
# ### 벡터화

# %%
df_positive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89917 entries, 0 to 89916
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         89917 non-null  int64
#  1   product_name       89917 non-null  object
#  2   review_date        89917 non-null  object
#  3   review_content     89917 non-null  object
#  4   review_star        89917 non-null  float64
#  5   review_writer      89917 non-null  object
#  6   tokenized_reviews  89917 non-null  object
#  7   replaced_review    87830 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.5+ MB

# %%
tokenized_comment=df_positive['replaced_review'].tolist()

# %%
type(tokenized_comment)
# Out:
# list

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
tokenized_comment
# Out:
# ['빨르다 감마 리놀렌산 여성 좋다 다해 초록색 엄청 비교 해보다 브리 결정 함량 높다 과정 마음 믿다 구매 좋다 알약 개봉시 터지다 주의 껍질 제거 습관 누르다 터지다 얼른 양제 실선 좋다 가위',
#  '상태 깔끔하다 좋다 두번째 구입 월경 증후군 구입 모르다 영향 다시 주문 알약 크기 크다 편입 판매 답글 판매 안녕하다 고객 브리 제품 구매 해주다 대단하다 감사하다 브리 제품 고객 건강 많다 도움 좋다 문의사항 연락 줄다 감사하다 브리 올리다',
#  '상태 깔끔하다 좋다 유트브 구매 피부 염증 좋다 판매 답글 판매 안녕하다 고객 브리 제품 구매 해주다 대단하다 감사하다 브리 제품 고객 건강 많다 도움 좋다 문의사항 연락 줄다 감사하다 브리 올리다',
#  '상태 깔끔하다 크다 아직 모르다 판매 답글 판매 안녕하다 고객 브리 제품 구매 해주다 대단하다 감사하다 브리 제품 고객 건강 많다 도움 좋다 문의사항 연락 줄다 감사하다 브리 올리다',
#  '빨르다 뛰어나다 케이스 보내다 달라 확인 보내다 총알 알약 크기 작다 아니다 가로 길이 이구 말랑말랑하다 심해지다 리뷰 읽다 찾아보다 구매 호주 영양 제로 약하다 원료 성분 달맞이꽃 자유 보라 강하다 양제 캐나다 산이 믿음직하다 좋다 가격 싸다 절반 가격 사서 미미하다 좋다 그렇다 복용 해보다 닫다',
#  '유통기간 바라보다 나이라 폐경 함유량 높다 제품 구매 캡슐 커서 마시다 야하다 모든 양제 그렇다 꾸준하다 복용 믿다 닫다',
#  '빨르다 섭취 필요하다 알아보다 달맞이 자유 보라 좋다 다해 선택 건강하다 반응 기대하다 섭취 빨르다',
#  '빨르다 뛰어나다 제품 제품 비다 함량 높다 좋다 도움 갱년기',
#  '두통 재다 감마 리놀렌산 함유량 높다 과정 괜찮다 편이 믿다 복용 중이 개인 전화번호 연락 치약 귀찮다 기도 개인 번호 연락 사은 품다 꺼리다 틀다 구매',
#  '상태 깔끔하다 갱년기 생기다 감마 리놀렌산 좋다 찾아보다 성분 좋다 구매 있딜 바라다',
# ...

# %%
countVectorizer = CountVectorizer()

# %%
countVectorizer.fit(tokenized_comment)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 countVectorizer.fit(tokenized_comment)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1339, in CountVectorizer.fit(self, raw_documents, y)
#    1323 def fit(self, raw_documents, y=None):
#    1324     """Learn a vocabulary dictionary of all tokens in the raw documents.
#    1325
#    1326     Parameters
#    (...)
#    1337         Fitted vectorizer.
#    1338     """
# -> 1339     self.fit_transform(raw_documents)
#    1340     return self
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1388, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1380             warnings.warn(
#    1381                 "Upper case characters found in"
#    1382                 " vocabulary while 'lowercase'"
# ...
