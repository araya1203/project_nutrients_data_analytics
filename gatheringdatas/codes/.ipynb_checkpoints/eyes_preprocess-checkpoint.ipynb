# %% [markdown]
# ## eyes 전처리 시작

# %%
# !pip install --user python-mecab-ko pyLDAvis

# %% [markdown]
# ### 쿠팡이랑 11번가 댓글 합치기

# %%
import pandas as pd

# %%
# df_eyes_coup=pd.read_csv('../datasets/eyes_coupang_raw.csv')
# df_eyes_11st=pd.read_csv('../datasets/eyes_eleven_raw.csv')

# %%
# df_eyes_raw=pd.concat([df_eyes_coup, df_eyes_11st], axis=0)
# df_eyes_raw

# %%
# df_eyes_raw.isnull().sum()

# %%
# df_eyes_raw=df_eyes_raw.dropna()

# %%
# df_eyes_raw[:2]

# %%
# df_eyes_raw=df_eyes_raw.drop(columns=['Unnamed: 0','_id'])

# %%
# df_eyes = df_eyes_raw.reset_index(drop=True)
# df_eyes

# %%
# df_eyes.to_csv('../datasets/eyes.csv')
df_eyes=pd.read_csv('../datasets/eyes.csv')

# %%
# df_eyes=df_eyes.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ### 불용어 처리 및 한글자 살리기 및 단어 치환,

# %% [markdown]
# #### 전처리 필요한 파일들 가져오기

# %%
# 대체어
df_replace = pd.read_excel('../datasets/sa_replace_list.xlsx')
df_replace[:5]
# Out:
#   before_replacement after_replacement
# 0                만졷ㄱ                만족
# 1               않좋아서              안좋아서
# 2               괜찮네요             보통이예요
# 3                시킬껭              시킬게요
# 4                  용                 요

# %%
# 불용어 
df_stop = pd.read_excel('../datasets/sa_stopword_list.xlsx')
df_stop[:5]
# Out:
#   stopword
# 0     가까스로
# 1       가량
# 2       가령
# 3       가민
# 4    가민커넥트

# %%
# 한글자 살리기
df_oneword=pd.read_excel('../datasets/sa_one_char_list.xlsx')
df_oneword[:5]
# Out:
#   one_char_keyword
# 0                컵
# 1                방
# 2                물
# 3                돈
# 4                꿈

# %% [markdown]
# #### 전처리 시작
# - 1. 단어 치환 하기
# - 2. 불용어 처리 하기
# - 3. okt 이용해서 stemming 하기 _ 부사를 동사 원형으로 바꿔서 보기
# <!-- mecab.pos로 토큰화하기 (.append(' '.join(token)) okt 하기  -->

# %%
## 단어 치환 함수 블로그 복사
def replace_word(review):
    for number in range(len(df_replace['before_replacement'])):
        try: 
            # 치환 단어만 데이터 치환
            if replace_list['before_replacement'][number] in review_content :
                review_content = review.replace(replace_list['before_replacement'][number], replace_list['after_replacement'][number])
        except: 
            pass
    return review

# %%
## 단어 치환 함수 블로그 복사
df_eyes['reveiw_replaced'] = ''
review_replaced_list = list()
for review in df_eyes['review_content']:
    review_replaced = replace_word(str(review))
    review_replaced_list.append(review_replaced)
df_eyes['reveiw_replaced'] = review_replaced_list
df_eyes[-10:]
# Out:
#        Unnamed: 0               product_name review_date  \
# 65660       65660  정관장 알파프로젝트 눈건강 500mg*90캡슐  2021.04.30
# 65661       65661  정관장 알파프로젝트 눈건강 500mg*90캡슐  2021.04.23
# 65662       65662  정관장 알파프로젝트 눈건강 500mg*90캡슐  2021.04.05
# 65663       65663  정관장 알파프로젝트 눈건강 500mg*90캡슐  2021.01.07
# 65664       65664  정관장 알파프로젝트 눈건강 500mg*90캡슐  2020.10.28
# 65665       65665  정관장 알파프로젝트 눈건강 500mg*90캡슐  2020.08.30
# 65666       65666  정관장 알파프로젝트 눈건강 500mg*90캡슐  2020.04.26
# 65667       65667  정관장 알파프로젝트 눈건강 500mg*90캡슐  2020.03.10
# 65668       65668  정관장 알파프로젝트 눈건강 500mg*90캡슐  2020.02.13
# 65669       65669  정관장 알파프로젝트 눈건강 500mg*90캡슐  2020.02.13
#
#                               review_content  review_star     review_writer  \
# 65660       배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요          5.0         lees*****
# 65661          배송 빨라요 성능 성능이 뛰어나요 유통기한 보통이에요          5.0            bjy8**
# 65662       배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요          5.0          qlqk****
# ...

# %%
# 내용의 토큰화 먼저_healthapp 복사
from mecab import MeCab
mecab = MeCab()
from konlpy.tag import Okt
okt = Okt()
stop=df_stop['stopword'].tolist()
oneword=df_oneword['one_char_keyword'].tolist()

# %%
# 불용어 제거 _ 블로그 및 chat
def stopword(text) :
    words = text.split() # text를 공백 기준으로 단어 분할한 뒤, 불용어 처리 진행 
    removed_words = [word for word in words if word not in stop]
    return ' '.join(removed_words)

# %%
## 불용어 처리 완료 
df_eyes['stopremoved_reviews']=df_eyes['reveiw_replaced'].apply(stopword)

# %%
from konlpy.tag import Okt

# Okt 형태소 분석기 인스턴스 생성
okt = Okt()

# 토큰화 결과를 담을 리스트 초기화
tokenized_reviews = []

# df_recovery['stopremoved_reviews'] 열의 각 텍스트에 대해 어구 추출 및 형태소 분석 수행
for review_text in df_eyes['stopremoved_reviews']:
    tokens = []
    try:
        # 어구 추출
        phrases = okt.phrases(review_text)
        
        # 추출된 어구에 대해 형태소 분석 및 원하는 품사(Noun, Verb, Adjective, Adverb, Exclamation, Determiner, Conjunction, Alpha) 선택
        for phrase in phrases:
            pos_result = okt.pos(phrase, norm=True, stem=True)
            for word, pos in pos_result:
                if pos in ['Noun', 'Verb', 'Adjective', 'Adverb', 'Exclamation', 'Determiner', 'Conjunction', 'Alpha']:
                    if len(word) > 1 or word in oneword:
                        tokens.append(word)
    except:
        pass
    tokenized_reviews.append(' '.join(tokens))

# %%
# tokenized_reviews를 df_recovery에 새로운 열로 추가
df_eyes['okt_reviews'] = tokenized_reviews

# %%
df_eyes['okt_reviews'][21769]
# Out:
# '어머니 사드 제품 제품 가격 대가 제품 가격 대가 부담 정말 정말 마게 정말 기분 사드 가격 대가 부담 마게 기분'

# %%
from collections import Counter

# 중복된 단어를 제거하는 함수 정의
def remove_duplicates(text):
    tokens = text.split()
    word_counts = Counter(tokens)
    unique_tokens = list(word_counts.keys())
    return ' '.join(unique_tokens)
# 중복된 단어를 제거한 결과를 새로운 열에 저장하고 기존 열을 덮어쓰려면 다음 코드를 사용할 수 있습니다.
df_eyes['okt_reviews'] = df_eyes['okt_reviews'].apply(remove_duplicates)

# %%
okt_token=df_eyes['okt_reviews']

# %%
# mecab_results = list()

# # df_recovery['tokenized_reviews'] 열의 각 텍스트에 대해 형태소 분석 수행
# for mecab_convert in okt_token:
#     try:
#         tokens = mecab.pos(mecab_convert)
#         mecab_results.append(tokens)
#     except:
#         pass

# # mecab_results: 위의 for문으로 mecab.pos하면 어떻게 나오는지 확인용.

# %%
## okt를 mecab으로 한번 더 
again_token = list()

# df_recovery['stopremoved_reviews'] 열의 각 텍스트에 대해 토큰화 수행
for review_text in df_eyes['okt_reviews']:
    add_tokens = []
    try:
        for word in mecab.pos(review_text):
            token, pos = word[0], word[1]
            if (len(token) > 1 or token in oneword) or (len(token) == 1 and pos in ['VV', 'VA']):
                add_tokens.append(token)
    except:
        pass
    again_token.append(' '.join(add_tokens))

# %%
df_eyes['mecab_reviews'] = again_token

# %%
df_eyes['mecab_reviews']
# Out:
# 0
# 1                     처음 효과 녹내장 통증 좋
# 2                     효과 여러 가지 유명 가격
# 3        위해 열심 사제품 가격 조율 소비자 좋 제품 조금
# 4
#                     ...
# 65665              배송 보통 성능 유통 기한 그냥
# 65666                          배송 성능
# 65667                    배송 성능 유통 기한
# 65668                    배송 성능 유통 기한
# 65669                 배송 보통 성능 유통 기한
# Name: mecab_reviews, Length: 65670, dtype: object

# %%
df_eyes[:5]
# Out:
#    Unnamed: 0              product_name review_date  \
# 0           0  여에스더 루테인&지아잔틴 눈, 30정, 1개  2023.06.02
# 1           1  여에스더 루테인&지아잔틴 눈, 30정, 1개  2022.11.15
# 2           2  여에스더 루테인&지아잔틴 눈, 30정, 1개  2022.06.29
# 3           3  여에스더 루테인&지아잔틴 눈, 30정, 2개  2022.11.03
# 4           4  여에스더 루테인&지아잔틴 눈, 30정, 4개  2023.08.11
#
#                                       review_content  review_star  \
# 0                        먹어보니 좋고 몇번더 먹어봐야 알수 있을것 같아요          5.0
# 1  꾸준하게 재구매 중입니다.\n처음엔 몰랐는데 효과가 있는거 같아요.\n눈이 많이 안...          5.0
# 2  아직까지 효과를 느끼지는 못하겠어요.\n눈이 여러가지로 좋지 않아서 의무적으로 먹어...          5.0
# 3  더 나빠지지않기위해 열심이먹고있어요 타사제품보다\n많이비쌉니다 가격을 더 조율해줄수...          4.0
# 4                                          잘 먹고 있습니다          5.0
#
#   review_writer                                    reveiw_replaced  \
# 0          최*정                         먹어보니 좋고 몇번더 먹어봐야 알수 있을것 같아요
# 1          정*섭   꾸준하게 재구매 중입니다.\n처음엔 몰랐는데 효과가 있는거 같아요.\n눈이 많이 안...
# ...

# %%
df_eyes.isnull().sum()
# Out:
# Unnamed: 0             0
# product_name           0
# review_date            0
# review_content         0
# review_star            0
# review_writer          0
# reveiw_replaced        0
# stopremoved_reviews    0
# okt_reviews            0
# mecab_reviews          0
# dtype: int64

# %%
df_eyes

# %%
df_eyes.to_csv('../datasets/eyes_preprocess.csv')

# %%
# 'mecab_reviews' 열의 모든 텍스트를 하나의 문자열로 결합
combined_text = ' '.join(df_eyes['mecab_reviews'])

# %%
from wordcloud import WordCloud

# %%
from collections import Counter

# %% [markdown]
# #### 토큰화 리뷰 빈도 계산

# %% [markdown]
# ###### 형태소의 빈도를 계산할때

# %%
from collections import Counter

# 단어 빈도수 카운트
word_counts = Counter(combined_text.split())

# %%
# 한글 폰트 경로 설정 (Windows 환경에 맞게 경로 수정)
font_path = 'C:/Windows/Fonts/malgun.ttf'

# 단어 빈도수 딕셔너리를 WordCloud에 전달
wordcloud = WordCloud(font_path=font_path, background_color='white')
wordcloud.generate_from_frequencies(word_counts)

# %%
wordcloud.words_
# Out:
# {'배송': 1.0,
#  '유통': 0.9971106452892188,
#  '기한': 0.9927482862160784,
#  '성능': 0.7786716522198931,
#  '보통': 0.3774856948614809,
#  '가격': 0.23728589503899686,
#  '구매': 0.2050686457802202,
#  '포장': 0.18867675108114743,
#  '상태': 0.15451438067720433,
#  '제품': 0.15077521575736974,
#  '오메가': 0.14040753120691934,
#  '효과': 0.11976658546258002,
#  '좋': 0.09903121636167922,
#  '먹': 0.09680282514682832,
#  '건강': 0.09627405435008404,
#  '복용': 0.09470662663116348,
#  '주문': 0.07907011878458256,
#  '구입': 0.07653957282873491,
#  '보': 0.05178176873831511,
#  '항상': 0.04638075274299851,
#  '종근당': 0.045965289974128,
#  '상품': 0.04199950899854588,
#  '하': 0.03669291635979076,
#  '늘': 0.03665514701716616,
#  '생각': 0.03589976016467433,
#  '양제': 0.03565425943761449,
#  '선물': 0.03372802296376032,
#  '부모': 0.03217947991615206,
#  '크기': 0.03146186240628482,
#  '비타민': 0.03129190036447416,
#  '안': 0.030007742715238043,
#  '빠르': 0.02925235586274621,
#  '도움': 0.028553623024191264,
#  '넘김': 0.02811927558400846,
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis('off') 
plt.show()

# %% [markdown]
# ###### 문장을 합쳐서 계산할때

# %%
text = ' '.join(df_eyes['mecab_reviews'])
text
# Out:
# ' 처음 효과 녹내장 통증 좋 효과 여러 가지 유명 가격 위해 열심 사제품 가격 조율 소비자 좋 제품 조금  지인 개월 뻑뻑 항상 트리 지다  배송 기본 달기 다리 구성 성분 지아 잔틴 오메가 배합 제품 마리 골드 망막 황반 황색 채소 과일 영양소 블루베리 좋 강력 항산 효과 식품 당근 연어 루테인 똑같 효능 색소 밀도 아스타 피로 도르다 개선 기능 복합 추출 물 mg EPA DHA 비타민 아연 셀레늄 캡슐 건강 인증 우수 기준 섭취 이유 일부 가장 안쪽 세포 밀집 사진기 필름 같 역할 신체 전후 시력 이전 완성 노화 차지 체내 합성 가능 되 유지 도움 건조 혈중 중성 지질 혈행 진행 자주 침침 느끼 컴퓨터 사용 운전 영양 공급 필요 방지 야맹증 두운 시각 적응 용법 알약 아잔 가지 함량 제약 회사 믿음 무엇 뻑뻑 복용 속도 나이 관리 인체 기관 많 활성산소 젊 사람 미리 황산 작용 청색 제거 내장 위험 선택 콜레스테롤 수치 사 포장 선물 주기 손색 벌써 주문 네이버 최저 가격 쿠팡 건강 인지 제조 구성 성분 지아 잔틴 오메가 배합 제품 마리 골드 망막 황반 황색 채소 과일 영양소 블루베리 좋 강력 항산 효과 식품 당근 연어 루테인 똑같 효능 색소 밀도 아스타 피로 도르다 개선 기능 복합 추출 물 mg EPA DHA 비타민 아연 셀레늄 캡슐 건강 인증 우수 기준 섭취 이유 일부 가장 안쪽 세포 밀집 사진기 필름 같 역할 신체 전후 시력 이전 완성 노화 차지 체내 합성 가능 되 유지 도움 건조 혈중 중성 지질 혈행 진행 자주 침침 느끼 컴퓨터 사용 운전 영양 공급 필요 방지 야맹증 두운 시각 적응 용법 알약 아잔 가지 나이 드 양제 물배 함량 제약 회사 믿음 복용 속도 쓰 리다 콜레스테롤 사 네이버 최저 가격 쿠팡 건강 인지 제조 구매 이유 매일 시간 스마트폰 티비 컴퓨터 모니터 위해 지아 잔틴 오메가 섭취 양제 복용 장점 특징 복합 추출 물 EPA DHA 함유 유지 노화 건조 건강 기능 인정 최대 mg 캡슐 포함 구성 PTP 개별 안심 포장 단점 크다 알약
# ...

# %%
# 단어로 쪼개기 
text_split = text.split()

# %%
# counter를 이용해서 중복 여부 count
from collections import Counter
Counter(text_split)
# Out:
# Counter({'처음': 643,
#          '효과': 6342,
#          '녹내장': 39,
#          '통증': 36,
#          '좋': 5244,
#          '여러': 448,
#          '가지': 658,
#          '유명': 123,
#          '가격': 12565,
#          '위해': 1198,
#          '열심': 22,
#          '사제품': 86,
#          '조율': 6,
#          '소비자': 37,
#          '제품': 7984,
#          '조금': 459,
#          '지인': 360,
#          '개월': 1438,
#          '뻑뻑': 463,
#          '항상': 2456,
#          '트리': 121,
#          '지다': 5,
#          '배송': 52953,
#          '기본': 113,
#          '달기': 5,
#          '다리': 83,
#          '구성': 256,
#          '성분': 1480,
#          '지아': 677,
#          '잔틴': 1074,
#          '오메가': 7435,
#          '배합': 17,
#          '마리': 123,
#          '골드': 231,
#          '망막': 68,
#          '황반': 278,
#          '황색': 22,
#          '채소': 18,
#          '과일': 23,
#          '영양소': 167,
#          '블루베리': 44,
#          '강력': 40,
#          '항산': 94,
#          '식품': 1208,
#          '당근': 35,
# ...

# %%
# 한글 폰트 경로 설정 (Windows 환경에 맞게 경로 수정)
font_path = 'C:/Windows/Fonts/malgun.ttf'

wordCloud = WordCloud(font_path=font_path, background_color='white') #인스턴스화 
wordCloud.generate_from_text(text)

# %%
# count 
wordCloud.words_
# Out:
# {'유통 기한': 1.0,
#  '성능 유통': 0.6911019692987468,
#  '배송 성능': 0.6450500895135794,
#  '기한 배송': 0.24166761893878794,
#  '배송 보통': 0.20894754885155983,
#  '포장 상태': 0.15139222184131337,
#  '기한 포장': 0.13573686816744754,
#  '가격 배송': 0.13470841427646366,
#  '보통 유통': 0.1314325981792557,
#  '보통 성능': 0.13061364415495372,
#  '성능 보통': 0.0882946710852093,
#  '구매 배송': 0.05410810193120786,
#  '기한 보통': 0.04873728716718089,
#  '상태 유통': 0.038890793433131454,
#  '배송 가격': 0.03626252237839485,
#  '효과 배송': 0.03391993296004266,
#  '상태 보통': 0.0336723422085095,
#  '배송 유통': 0.033405706014550715,
#  '기한 오메가': 0.02902525425665638,
#  '보통 가격': 0.024168666438121357,
#  '제품 배송': 0.02296880356530682,
#  '기한 항상': 0.019788214680227022,
#  '구입 배송': 0.01940730583171447,
#  '기한 제품': 0.01933112406201196,
#  '주문 배송': 0.01839789738315621,
#  '양제': 0.018055079419494916,
#  '보통 포장': 0.017731306898259247,
#  '복용 배송': 0.01746467070430046,
#  '섭취': 0.01698853464365977,
#  '기한 건강': 0.016512398583019082,
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off') 
plt.show()

# %% [markdown]
# ### 벡터화 진행
