# %%
# %conda install pymongo

# %%
import pymongo as mg
import pandas as pd

# %%
mg.__version__
# Out:
# '3.12.0'

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['project_nutrients']

# %%
collection = database['11st_corelsterolsupplement_review']

# %%
cursor = collection.find({})

# %%
list_11stcho = list(cursor)

# %%
list_11stcho
# Out:
# [{'_id': ObjectId('650d8884b2af41f5ca5ba6aa'),
#   'product_name': '브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 / 콜레스테롤 개선',
#   'review_writer': '지오됴됴',
#   'review_date': '2021.03.19',
#   'review_star': '5',
#   'review_content': '배송 빨라요 성능 보통이에요 유통기한 기한이 넉넉해요\n감마리놀렌산이 여성에게 좋다해서 초록색창에서 엄청 비교해보다가 브리오로 결정했어요!\n함량도 높고 제조과정이 마음에 들었어요\n믿고 구매했는데 효과가 있으면 좋겠네요\n\n알약 개봉시 터짐 주의에 따라 껍질부터 제거하고 먹는거 중☆☆요 습관처럼 눌러서 뜯다가 하나가 살짝 터져서 얼른 입으로 슝\n\n다른 영양제 처럼 하나씩 뜯기게끔 실선이 있으면 좋겠어요\n어디 들고 나갈 때 가위로 오려서 가요...ㅎㅎㅎ\n더보기\n상세보기\n상세보기'},
#  {'_id': ObjectId('650d8884b2af41f5ca5ba6ab'),
#   'product_name': '브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 / 콜레스테롤 개선',
#   'review_writer': 'ju82**',
#   'review_date': '2023.07.05',
#   'review_star': '5',
# ...

# %%
df_11stcho = pd.DataFrame(list_11stcho)

# %%
df_11stcho
# Out:
#                            _id  \
# 0     650d8884b2af41f5ca5ba6aa
# 1     650d8884b2af41f5ca5ba6ab
# 2     650d8884b2af41f5ca5ba6ac
# 3     650d8884b2af41f5ca5ba6ad
# 4     650d8884b2af41f5ca5ba6ae
# ...                        ...
# 6981  65106ab5285489daa54c1d30
# 6982  65106ab5285489daa54c1d31
# 6983  65106ab5285489daa54c1d32
# 6984  65106ab5285489daa54c1d33
# 6985  65106ab5285489daa54c1d34
#
#                                            product_name review_writer  \
# 0     브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...          지오됴됴
# 1     브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...        ju82**
# 2     브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...        sns2**
# 3     브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...       gus1***
# 4     브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...    gksd******
# ...                                                 ...           ...
# 6981                    레이델 폴리코사놀5 200mg x 30정 x 6박스 JJ
# ...

# %%
df_11stcho.to_csv('../datasets/11st_corelsterol_review.csv')

# %%
df_11stcho['product_name'].value_counts()
# Out:
# 브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 / 콜레스테롤 개선                      1534
# 캐나다 6개월분 알티지오메가3 1200 비타민D rTG 오메가3 콜레스테롤                                    1058
# 써큐시안 블러드케어 - 혈압 혈행 혈액순환 콜레스테롤 관리 홍국 코엔자임q10 오메가3, 3박스 3개월                    1048
# 뉴트리 보라지오일 감마리놀렌산 보라지유 오메가6 / 달맞이꽃종자유 콜레스테롤 갱년기 영양제 식물성 90캡슐 3개월 1박스           952
# 해외[아이허브] 라이프익스텐션 레시틴 454g, 인지질 콜레스테롤 Life Extension 포스파티딜콜린                   368
# 오메가써큐텐 콜레스테롤 낮추는 영양제 알티지오메가3 홍국 모나콜린K 중성지질 HDL LDL 개선                         346
# 모어네이처 콜레스테롤 케어 엽산 발효 홍국 1박스                                                   196
# [콜레스테롤 수치개선] 레이델 폴리코사놀 5 30정 X 6박스                                            127
# 뉴스킨 콜레스틴/혈관건강/콜레스테롤건강/홍국함유                                                    110
# 레이델 폴리코사놀5 200mg X 30정 6박스                                                    106
# [세노비스] 수퍼바이오틱스 콜레스테롤 (30캡슐/30일분) x 2개 세트                                      102
# ...
