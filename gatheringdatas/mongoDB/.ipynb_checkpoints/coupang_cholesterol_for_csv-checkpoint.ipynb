# %%
# %conda install pymongo

# %%
import pymongo as mg
import pandas as pd

# %%
mg.__version__
# Out:
# '3.12.0'

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['project_nutrients']

# %%
collection = database['coupang_cholesterol_review']

# %%
cursor = collection.find({})

# %%
list_coupangcho = list(cursor)

# %%
list_coupangcho
# Out:
# [{'_id': ObjectId('6510ec4f1b849cc9d8ad1c08'),
#   'product_name': '파이토웨이 써큐시안 블러드케어, 60정, 3개',
#   'review_date': '2023.08.25',
#   'review_content': '전 몇년전에 건강검진때 당뇨 전단계라고 해서, 당시는 운동 식사조절을 해서 정상 수치로 되었습니다.\n\n그 후 다시 먹기 시작하고 운동도 안하면서,\n요즘 혈당이 정상을 넘어 높아졌습니다.\n\n당뇨병에 걸릴까봐 걱정이 컸고,\n부모님도 당뇨 합병증으로 돌아가셔서,\n다시 각성을 했습니다.\n\n그 와중에 친구에게 걱정을 터놓았고, 써큐시안을 추천해 주었습니다.\n\n친구 아는 사람이 이것먹고 혈관 건강해졌다고 했고요.\n\n신뢰가는 친구의 권유로 구매하게 되었습니다.\n\n혈관의 피가 건강해야 한다는건 알고 있어서 오메가 3는 복용했었는데,\n\n써큐시안에는 오메가3, 홍국, 엽산, 코엔자임 Q와 12가지 필요한 영양소가 들어있어서,\n앞으로 꾸준히 복용하고자 합니다.\n\n저녁때 1회 2알을 저녁 식사후 2시간후 복용하고, 2시간 후 잠드는 섭취 Tip대로 했습니다.\n\nㆍ복용후 변화\n1. 평소 오른쪽이 뭔가 막혀 있는 느낌이 들었고, 아마도 혈액순환때문이었던 것 같았습니다.\n복용후 변화는 그런 느낌이 사라졌습니다.\n\n2. 혈관 종합 영양제라 이 영양제만 복용하면되어서 편합니다.\n\n3. 복용시 목넘김이 좋아 불편함이 없습니다.\n\nㆍ단점\nㅡ다소 비싸다.',
#   'review_star': '5',
#   'review_writer': '박로즈마리 '},
#  {'_id': ObjectId('6510ec4f1b849cc9d8ad1c09'),
#   'product_name': '파이토웨이 써큐시안 블러드케어, 60정, 3개',
#   'review_date': '2023.06.25',
# ...

# %%
df_coupangcho = pd.DataFrame(list_coupangcho)

# %%
df_coupangcho[:2]
# Out:
#                         _id               product_name review_date  \
# 0  6510ec4f1b849cc9d8ad1c08  파이토웨이 써큐시안 블러드케어, 60정, 3개  2023.08.25
# 1  6510ec4f1b849cc9d8ad1c09  파이토웨이 써큐시안 블러드케어, 60정, 3개  2023.06.25
#
#                                       review_content review_star review_writer
# 0  전 몇년전에 건강검진때 당뇨 전단계라고 해서, 당시는 운동 식사조절을 해서 정상 수...           5        박로즈마리
# 1  재작년에 코ㄹ나로 인해 건강검진을 받았을 당시\n백수생활로 살이 많이 찐상태로 미루...           5          김*현

# %%
df_coupangcho.to_csv('../datasets/coupang_corelsterol_review.csv')

# %%
len(df_coupangcho)
# Out:
# 4500

# %%
df_coupangcho['product_name'].value_counts().index
# Out:
# Index(['연세 세브란스케어 블러드케어 X5 써큐맥스 플러스, 1box, 60캡슐',
#        '종근당건강 프로메가 오메가3 트리플 장용성, 60정, 2개', '파이토웨이 써큐시안 블러드케어, 60정, 3개',
#        '홀리데이즈 크랜베리 영양제, 90정, 1개', '종근당건강 프로메가 알티지 오메가3 플러스, 60정, 3개',
#        '스완슨 폴리코사놀 20mg 캡슐, 60정, 1개',
#        '뉴트리코스트 콜레우스 포스콜리 500mg 캡슐, 60개입, 1개, 60정',
#        '마이라이프 내추럴스 폴리코사놀 25mg (총지방족 95%/옥타코사놀 61%), 120정, 2개',
#        '종근당건강 프로메가 알티지 오메가3 듀얼 플러스, 60정, 3개',
#        'JW중외제약 혈당건강 바나바정제 혈당 조절 바나바잎추출물, 60정, 1개',
#        ...
#        '[공식] 뉴트리코어 x Dr 블루션 블러딕스 (혈압 혈당 콜레스테롤 혈행개선), 5개, 60정',
#        '더리얼 메모리캡슐 포스파티딜세린+징코 722mg x 60캡슐 5개(5개월분), 5개',
#        '레이델 쿠바산 폴리코사놀20 x 7박스 (198mg x 30정 총 210정), 7개',
#        '[본사직영] 대웅제약 에너씨슬 밀크씨슬 루테인 아스타잔틴, 30정, 4개',
#        '대웅제약 에너씨슬 밀크씨슬 루테인 아스타잔틴 24g, 30정, 1개',
#        '닥터브라이언 폴리코사놀20mg (3개월분), 90정, 1개', '대웅제약 에너씨슬 밀크씨슬 간건강, 30정, 3개',
#        '큐라에스 리커버리칸 간수치 저하 간영양제 밀크씨슬, 6박스, 6개',
#        '콜레스타 LDL HDL 콜레스테롤 혈압 동시 케어 식약처 기능성 인정 홍국 코엔자임Q10, 6개, 60정',
# ...

# %%
len(df_coupangcho['product_name'].value_counts().index)
# Out:
# 194

# %%
df_coupangcho.isnull().sum()
# Out:
# _id               0
# product_name      0
# review_date       0
# review_content    0
# review_star       0
# review_writer     0
# dtype: int64

# %%
df = pd.read_csv('../datasets/coupang_corelsterol_review.csv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# _id                  0
# product_name         9
# review_date          9
# review_content    1112
# review_star          9
# review_writer        9
# dtype: int64

# %%
df_dropna = df.dropna()

# %%
df_dropna.isnull().sum()
# Out:
# Unnamed: 0        0
# _id               0
# product_name      0
# review_date       0
# review_content    0
# review_star       0
# review_writer     0
# dtype: int64

# %%
df_dropna_drop_duplicates= df_dropna.drop_duplicates()

# %%
df_dropna_drop_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3388 entries, 0 to 4465
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      3388 non-null   int64
#  1   _id             3388 non-null   object
#  2   product_name    3388 non-null   object
#  3   review_date     3388 non-null   object
#  4   review_content  3388 non-null   object
#  5   review_star     3388 non-null   float64
#  6   review_writer   3388 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 211.8+ KB

# %%
df_dropna_drop_duplicates.value_counts()
# Out:
# Unnamed: 0  _id                       product_name                               review_date  review_content                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# ...

# %%
# null 제거함, 중복 제거함
df_dropna_drop_duplicates.to_csv('../datasets/coupang_cho_no_duplicates.csv')
