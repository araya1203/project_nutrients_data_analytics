# %%
# %conda install pymongo

# %%
import pymongo as mg
import pandas as pd

# %%
mg.__version__
# Out:
# '3.12.0'

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['project_nutrients']

# %%
collection = database['11st_eyes_images']

# %%
cursor = collection.find({})

# %%
list_11stcho = list(cursor)

# %%
list_11stcho
# Out:
# [{'_id': ObjectId('65276cd8e695ed5488091cdf'),
#   'product_name': '브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 / 콜레스테롤 개선',
#   'product_link': 'https://www.11st.co.kr/products/12639316?&trTypeCd=05&trCtgrNo=585021&checkCtlgPrd=true',
#   'product_image': 'https://cdn.011st.com/11dims/resize/248/11src/product/12639316/L300.jpg?165000000'},
#  {'_id': ObjectId('65276cd8e695ed5488091ce0'),
#   'product_name': '캐나다 알티지오메가3 1200 비타민D rTG 오메가3 콜레스테롤 내추럴영 90캡슐 X 2병 (6개월분)',
#   'product_link': 'https://www.11st.co.kr/products/3208992856?&trTypeCd=05&trCtgrNo=585021&checkCtlgPrd=true',
#   'product_image': 'https://cdn.011st.com/11dims/resize/248/11src/product/3208992856/L300.jpg?644000000'},
#  {'_id': ObjectId('65276cd8e695ed5488091ce1'),
#   'product_name': '뉴트리 보라지오일 감마리놀렌산 보라지유 오메가6 / 달맞이꽃종자유 콜레스테롤 갱년기 영양제 식물성 90캡슐 3개월 1박스',
#   'product_link': 'https://www.11st.co.kr/products/1572094809?&trTypeCd=MAS101&trCtgrNo=585021&checkCtlgPrd=true',
# ...

# %%
df_11stcho = pd.DataFrame(list_11stcho)

# %%
df_11stcho
# Out:
#                          _id  \
# 0   65276cd8e695ed5488091cdf
# 1   65276cd8e695ed5488091ce0
# 2   65276cd8e695ed5488091ce1
# 3   65276cd8e695ed5488091ce2
# 4   65276cd8e695ed5488091ce3
# 5   65276cd8e695ed5488091ce4
# 6   65276cd8e695ed5488091ce5
# 7   65276cd8e695ed5488091ce6
# 8   65276cd8e695ed5488091ce7
# 9   65276cd8e695ed5488091ce8
# 10  65276cd8e695ed5488091ce9
# 11  65276cd8e695ed5488091cea
# 12  65276cd8e695ed5488091ceb
# 13  65276cd8e695ed5488091cec
# 14  65276cd8e695ed5488091ced
# 15  65276cd8e695ed5488091cee
# 16  65276cd8e695ed5488091cef
# 17  65276cd8e695ed5488091cf0
# 18  65276cd8e695ed5488091cf1
# 19  65276cd8e695ed5488091cf2
# 20  65276cd8e695ed5488091cf3
# 21  65276cd8e695ed5488091cf4
# 22  65276cd8e695ed5488091cf5
# 23  65276cd8e695ed5488091cf6
# 24  65276cd8e695ed5488091cf7
# 25  65276cd8e695ed5488091cf8
# 26  65276cd8e695ed5488091cf9
# 27  65276cd8e695ed5488091cfa
# 28  65276cd8e695ed5488091cfb
# 29  65276cd8e695ed5488091cfc
# 30  65276cd8e695ed5488091cfd
# ...

# %%
# 불필요한 columns 제거 
df_11stcho = df_11stcho.drop(columns = ['_id'])
df_11stcho
# Out:
#                                          product_name  \
# 0   브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 /...
# 1   캐나다 알티지오메가3 1200 비타민D rTG 오메가3 콜레스테롤 내추럴영 90캡슐...
# 2   뉴트리 보라지오일 감마리놀렌산 보라지유 오메가6 / 달맞이꽃종자유 콜레스테롤 갱년기...
# 3   해외[아이허브] 라이프익스텐션 레시틴 454g, 인지질 콜레스테롤 Life Exte...
# 4   오메가써큐텐 콜레스테롤 낮추는 영양제 알티지오메가3 홍국 모나콜린K 중성지질 HDL...
# 5   써큐시안 블러드케어 - 혈압 혈행 혈액순환 콜레스테롤 관리 홍국 코엔자임q10 오메...
# 6   써큐시안 블러드케어 - 혈압 혈행 혈액순환 콜레스테롤 관리 홍국 코엔자임q10 오메...
# 7   써큐시안 블러드케어 - 혈압 혈행 혈액순환 콜레스테롤 관리 홍국 코엔자임q10 오메...
# 8   써큐시안 블러드케어 - 혈압 혈행 혈액순환 콜레스테롤 관리 홍국 코엔자임q10 오메...
# 9                         모어네이처 콜레스테롤 케어 엽산 발효 홍국 1박스
# 10                 [콜레스테롤 수치개선] 레이델 폴리코사놀 5 30정 X 6박스
# 11           [세노비스] 수퍼바이오틱스 콜레스테롤 (30캡슐/30일분) x 2개 세트
# 12  해외[아이허브] Kyolic 마늘 추출물 1000mg 60캡슐, 심장 혈관 키요릭 ...
# 13   고야민 액티브 31개국 특허 콜레스테롤 여주 영양제 추출물 건강식품 90정 1병 1개월
# 14  파이토웨이 써큐시안 블러드케어 혈액 순환 영양제(콜레스테롤, 혈압, 혈관) 3중케어 in
# 15  내츄럴플러스 100% 대두 레시틴 60캡슐 3박스 / 식물성 인지질60% 콜레스테롤 개선
# ...

# %%
df_11stcho.to_csv('../datasets/cholesterol_data/11st_corelsterolsupplement_images.csv')

# %%
df_11stcho['product_name'].value_counts()
# Out:
# product_name
# 브리오 보라지오일 감마리놀렌산 300 / 오메가6 보라지유 달맞이꽃종자유 영양제 / 콜레스테롤 개선                      1
# 캐나다 알티지오메가3 1200 비타민D rTG 오메가3 콜레스테롤 내추럴영 90캡슐 X 2병 (6개월분)                   1
# 해외쿄릭 숙성마늘 피토스테롤 콜레스테롤 포뮬라 107 240켑슐                                          1
# [세노비스] 수퍼바이오틱스 콜레스테롤(30캡슐/30일분) 2개 세트                                        1
# 세라엑스 혈당콜레스테롤 프로케어 900mgx60정                                                  1
# 유비큐스 60정 코엔자임Q10 혈당 혈압 콜레스테롤 홍국 바나바잎 영양제                                     1
# 콜레스타 콜레스테롤 영양제 900mg 60정 6박스 6개월분 코엔자임Q10 코큐텐 홍국 바나바잎 은행잎추출물                 1
# 레이델 폴리코사놀5 200mg X 30정 12박스_MC                                               1
# 해외쿄릭 숙성 마늘 추출물 갈릭 콜레스테롤 포뮬러 104 300 캡슐 Kyolic                                1
# RAYDEL 레이델 폴리코사놀5 김명민 콜레스테롤 영양제 30정 6개(6개월분)                                 1
# 일동제약 지큐랩 콜레스테롤 솔루션 13.5g x 2박스                                               1
# 일동제약 지큐랩 콜레스테롤 솔루션 13.5g x 1박스                                               1
# ...
